# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 624

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1



# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    city_weather = requests.get(city_url).json()
    
 # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | adamstown
# Processing Record 3 of Set 1 | grytviken
# Processing Record 4 of Set 1 | susuman
# Processing Record 5 of Set 1 | papatowai
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | whitehorse
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | espargos
# City not found. Skipping...
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | edinburgh of the seven seas
# Processing Record 13 of Set 1 | port douglas
# Processing Record 14 of Set 1 | skrunda
# Processing Record 15 of Set 1 | keflavik
# Processing Record 16 of Set 1 | kadnikov
# Processing Record 17 of Set 1 | blackmans bay
# Processing Record 18 of Set 1 | nanakuli
# Processing Record 19 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 20 of Set 1 | tanout
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | waitangi
# Processing Record 23 of Set 1 | karratha
# Processing Record 24 of Set 1 | puerto natales
# Processing Record 25 of Set 1 | road town
# Processing Record 26 of Set 1 | anadyr
# Processing Record 27 of Set 1 | opole
# Processing Record 28 of Set 1 | ulladulla
# Processing Record 29 of Set 1 | lompoc
# Processing Record 30 of Set 1 | kyshtovka
# Processing Record 31 of Set 1 | west island
# Processing Record 32 of Set 1 | rongelap
# Processing Record 33 of Set 1 | olonkinbyen
# Processing Record 34 of Set 1 | pisco
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | tommot
# Processing Record 37 of Set 1 | montevallo
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | carbonear
# Processing Record 41 of Set 1 | labuan
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | dudinka
# Processing Record 44 of Set 1 | atafu village
# Processing Record 45 of Set 1 | chaman
# Processing Record 46 of Set 1 | kirakira
# Processing Record 47 of Set 1 | whitby
# Processing Record 48 of Set 1 | stiens
# Processing Record 49 of Set 1 | cabo san lucas
# Processing Record 50 of Set 1 | olyokminsk
# Processing Record 0 of Set 2 | qaqortoq
# Processing Record 1 of Set 2 | ghadamis
# Processing Record 2 of Set 2 | ixtapa
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | yendi
# Processing Record 5 of Set 2 | puerto san jose
# Processing Record 6 of Set 2 | pachino
# Processing Record 7 of Set 2 | kapa'a
# Processing Record 8 of Set 2 | leava
# Processing Record 9 of Set 2 | borogontsy
# Processing Record 10 of Set 2 | wotje
# Processing Record 11 of Set 2 | arraias
# Processing Record 12 of Set 2 | seryshevo
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | benghazi
# Processing Record 16 of Set 2 | margaret river
# Processing Record 17 of Set 2 | kununurra
# Processing Record 36 of Set 3 | tsiombe
# Processing Record 37 of Set 3 | juneau
# Processing Record 38 of Set 3 | hamada
# Processing Record 39 of Set 3 | kulhudhuffushi
# Processing Record 40 of Set 3 | joshimath
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | akhaltsikhe
# Processing Record 43 of Set 3 | aykhal
# Processing Record 44 of Set 3 | mulchen
# Processing Record 45 of Set 3 | badger
# Processing Record 46 of Set 3 | tarko-sale
# Processing Record 47 of Set 3 | geraldton
# Processing Record 48 of Set 3 | kill devil hills
# Processing Record 49 of Set 3 | sandnessjoen
# Processing Record 0 of Set 4 | isheyevka
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | hamilton
# Processing Record 3 of Set 4 | iskateley
# Processing Record 4 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 5 of Set 4 | safi
# Processing Record 6 of Set 4 | belfast
# Processing Record 7 of Set 4 | kharan
# Processing Record 8 of Set 4 | ostersund
# Processing Record 9 of Set 4 | filingue
# Processing Record 10 of Set 4 | jiangyou
# Processing Record 11 of Set 4 | tocopilla
# Processing Record 12 of Set 4 | mossel bay
# Processing Record 13 of Set 4 | rio grande
# Processing Record 14 of Set 4 | bilibino
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | san patricio
# Processing Record 17 of Set 4 | guarapari
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | vadso
# Processing Record 20 of Set 4 | kangding
# Processing Record 21 of Set 4 | barcelos
# Processing Record 22 of Set 4 | hashtrud
# Processing Record 23 of Set 4 | san luis de la loma
# Processing Record 24 of Set 4 | fort st. john
# Processing Record 25 of Set 4 | yaren
# Processing Record 26 of Set 4 | balabac
# Processing Record 27 of Set 4 | tazacorte
# Processing Record 28 of Set 4 | pandan
# Processing Record 29 of Set 4 | lianran
# Processing Record 30 of Set 4 | veraval
# Processing Record 31 of Set 4 | nova sintra
# Processing Record 32 of Set 4 | ornskoldsvik
# Processing Record 33 of Set 4 | college
# Processing Record 34 of Set 4 | st. john's
# Processing Record 35 of Set 4 | longyearbyen
# Processing Record 36 of Set 4 | morehead city
# Processing Record 37 of Set 4 | vilyuchinsk
# Processing Record 38 of Set 4 | happy valley-goose bay
# Processing Record 39 of Set 4 | cidade velha
# Processing Record 40 of Set 4 | gremyachinsk
# Processing Record 41 of Set 4 | pak phanang
# Processing Record 42 of Set 4 | mount isa
# Processing Record 43 of Set 4 | n'zeto
# Processing Record 44 of Set 4 | fortuna
# Processing Record 45 of Set 4 | spassk
# Processing Record 46 of Set 4 | sherghati
# Processing Record 47 of Set 4 | machali
# Processing Record 48 of Set 4 | chiang klang
# Processing Record 49 of Set 4 | fale old settlement
# Processing Record 0 of Set 5 | tanjung pandan
# Processing Record 1 of Set 5 | bardai
# Processing Record 2 of Set 5 | oranjemund
# Processing Record 3 of Set 5 | tolanaro
# Processing Record 4 of Set 5 | east london
# Processing Record 5 of Set 5 | 'izbat al burj
# City not found. Skipping...
# Processing Record 6 of Set 5 | cortez
# Processing Record 7 of Set 5 | vuktyl
# Processing Record 8 of Set 5 | barra do garcas
# Processing Record 9 of Set 5 | kralendijk
# Processing Record 10 of Set 5 | dunedin
# Processing Record 11 of Set 5 | bongao
# Processing Record 12 of Set 5 | bel ombre
# Processing Record 13 of Set 5 | wewak
# Processing Record 14 of Set 5 | eastham
# Processing Record 15 of Set 5 | ust-nera
# Processing Record 16 of Set 5 | palmas
# Processing Record 17 of Set 5 | coahuayana de hidalgo
# Processing Record 18 of Set 5 | kindu
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | nuuk
# Processing Record 21 of Set 5 | uturoa
# Processing Record 22 of Set 5 | cat ba
# City not found. Skipping...
# Processing Record 23 of Set 5 | namsos
# Processing Record 24 of Set 5 | cascais
# Processing Record 25 of Set 5 | palmer
# Processing Record 26 of Set 5 | nahiyat ash shinafiyah
# Processing Record 27 of Set 5 | maintirano
# Processing Record 28 of Set 5 | sinop
# Processing Record 29 of Set 5 | axim
# Processing Record 30 of Set 5 | pariaman
# Processing Record 31 of Set 5 | pontal
# Processing Record 32 of Set 5 | longboat key
# Processing Record 33 of Set 5 | soio
# Processing Record 34 of Set 5 | roxas
# Processing Record 35 of Set 5 | pagar alam
# Processing Record 36 of Set 5 | wangkui
# Processing Record 37 of Set 5 | byron bay
# Processing Record 38 of Set 5 | kidal
# Processing Record 39 of Set 5 | kyzyl-mazhalyk
# Processing Record 40 of Set 5 | atkarsk
# Processing Record 41 of Set 5 | klyuchi
# Processing Record 42 of Set 5 | paran'ga
# Processing Record 43 of Set 5 | kavieng
# Processing Record 44 of Set 5 | bambanglipuro
# Processing Record 45 of Set 5 | sittwe
# Processing Record 46 of Set 5 | constantia
# Processing Record 47 of Set 5 | bikenibeu village
# Processing Record 48 of Set 5 | trairi
# Processing Record 49 of Set 5 | bubaque
# Processing Record 0 of Set 6 | vernon
# Processing Record 1 of Set 6 | cartagena
# Processing Record 2 of Set 6 | floro
# Processing Record 3 of Set 6 | sainte-menehould
# Processing Record 4 of Set 6 | dakhla
# Processing Record 5 of Set 6 | ha'il
# Processing Record 6 of Set 6 | amga
# Processing Record 7 of Set 6 | idri
# Processing Record 8 of Set 6 | cockburn town
# Processing Record 9 of Set 6 | zaozersk
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | dolyna
# Processing Record 12 of Set 6 | khorostkiv
# Processing Record 13 of Set 6 | hithadhoo
# Processing Record 14 of Set 6 | turpan
# Processing Record 15 of Set 6 | jiuquan
# Processing Record 16 of Set 6 | kapuskasing
# Processing Record 17 of Set 6 | presidente medici
# Processing Record 18 of Set 6 | baluntaicun
# City not found. Skipping...
# Processing Record 19 of Set 6 | argo
# Processing Record 20 of Set 6 | stanley
# Processing Record 21 of Set 6 | nguruka
# Processing Record 6 of Set 9 | novodvinsk
# Processing Record 7 of Set 9 | arenapolis
# Processing Record 8 of Set 9 | laojunmiao
# Processing Record 9 of Set 9 | kalengwa
# Processing Record 10 of Set 9 | jaithari
# Processing Record 11 of Set 9 | bengkulu
# Processing Record 12 of Set 9 | riyadh
# Processing Record 13 of Set 9 | vasto
# Processing Record 14 of Set 9 | coquimbo
# Processing Record 15 of Set 9 | argostolion
# Processing Record 16 of Set 9 | al 'alamayn
# City not found. Skipping...
# Processing Record 17 of Set 9 | tadine
# Processing Record 18 of Set 9 | bereket
# Processing Record 19 of Set 9 | ghanzi
# Processing Record 20 of Set 9 | neryungri
# Processing Record 21 of Set 9 | chibougamau
# Processing Record 22 of Set 9 | los llanos de aridane
# Processing Record 23 of Set 9 | codrington
# Processing Record 24 of Set 9 | kodiak
# Processing Record 25 of Set 9 | avarua
# Processing Record 26 of Set 9 | rybinsk
# Processing Record 27 of Set 9 | peace river
# Processing Record 28 of Set 9 | gejiu
# Processing Record 29 of Set 9 | dire dawa
# Processing Record 30 of Set 9 | howell
# Processing Record 31 of Set 9 | selma
# Processing Record 32 of Set 9 | roma
# Processing Record 33 of Set 9 | taitung city
# Processing Record 34 of Set 9 | skeldon
# Processing Record 35 of Set 9 | erenhot
# Processing Record 36 of Set 9 | kapoeta
# Processing Record 37 of Set 9 | trinidad
# Processing Record 38 of Set 9 | malango
# Processing Record 39 of Set 9 | mata-utu
# Processing Record 40 of Set 9 | carupano
# Processing Record 41 of Set 9 | rio preto da eva
# Processing Record 42 of Set 9 | east tamworth
# Processing Record 43 of Set 9 | chonchi
# Processing Record 44 of Set 9 | southside
# Processing Record 45 of Set 9 | isola di capo rizzuto
# Processing Record 46 of Set 9 | trimbak
# Processing Record 47 of Set 9 | moires
# Processing Record 48 of Set 9 | ad darb
# Processing Record 49 of Set 9 | lethem
# Processing Record 0 of Set 10 | santa terezinha
# Processing Record 1 of Set 10 | thinadhoo
# Processing Record 2 of Set 10 | monte alegre
# Processing Record 3 of Set 10 | wardenburg
# Processing Record 4 of Set 10 | yugorsk
# Processing Record 5 of Set 10 | saint john
# Processing Record 6 of Set 10 | elmendorf air force base
# City not found. Skipping...
# Processing Record 7 of Set 10 | labytnangi
# Processing Record 8 of Set 10 | takhatgarh
# Processing Record 9 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 10 of Set 10 | alvorada
# Processing Record 11 of Set 10 | gaalkacyo
# Processing Record 12 of Set 10 | kita
# Processing Record 13 of Set 10 | samaro
# Processing Record 14 of Set 10 | kuala belait
# Processing Record 15 of Set 10 | san antonio de pale
# Processing Record 16 of Set 10 | illizi
# Processing Record 17 of Set 10 | letlhakane
# Processing Record 18 of Set 10 | lakatoro
# Processing Record 19 of Set 10 | cross lanes
# Processing Record 20 of Set 10 | puerto aysen
# Processing Record 21 of Set 10 | nishinoomote
# Processing Record 22 of Set 10 | voi
# Processing Record 23 of Set 10 | cradock
# Processing Record 24 of Set 10 | greymouth
# Processing Record 25 of Set 10 | polyarnyy
# Processing Record 26 of Set 10 | mournies
# Processing Record 27 of Set 10 | queenstown
# Processing Record 28 of Set 10 | itacare
# Processing Record 29 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 30 of Set 10 | merizo village
# Processing Record 31 of Set 10 | villa de soto
# Processing Record 32 of Set 10 | san rafael
# Processing Record 33 of Set 10 | americus
# Processing Record 34 of Set 10 | paita
# Processing Record 35 of Set 10 | mount pearl
# Processing Record 36 of Set 10 | kantilo
# Processing Record 37 of Set 10 | pozos de gamboa
# Processing Record 38 of Set 10 | whangarei
# Processing Record 39 of Set 10 | makokou
# Processing Record 40 of Set 10 | dzhambeyty
# Processing Record 41 of Set 10 | el-tor
# Processing Record 42 of Set 10 | harper
# Processing Record 43 of Set 10 | puerto baquerizo moreno
# Processing Record 44 of Set 10 | sao tome
# Processing Record 45 of Set 10 | kutloanong
# Processing Record 46 of Set 10 | ouarzazat
# Processing Record 47 of Set 10 | la ronge
# Processing Record 48 of Set 10 | bismarck
# Processing Record 49 of Set 10 | bull savanna
# Processing Record 0 of Set 11 | puerto lopez
# Processing Record 1 of Set 11 | mahibadhoo
# Processing Record 2 of Set 11 | jincheng
# Processing Record 3 of Set 11 | itaituba
# Processing Record 4 of Set 11 | nikolayevsk-on-amure
# Processing Record 5 of Set 11 | porto seguro
# Processing Record 6 of Set 11 | hefei
# Processing Record 7 of Set 11 | yamada
# Processing Record 8 of Set 11 | banff
# Processing Record 9 of Set 11 | rantauprapat
# Processing Record 10 of Set 11 | tromso
# Processing Record 11 of Set 11 | vangviang
# Processing Record 12 of Set 11 | burang
# Processing Record 13 of Set 11 | gueltat zemmour
# City not found. Skipping...
# Processing Record 14 of Set 11 | richards bay
# Processing Record 15 of Set 11 | loikaw
# Processing Record 16 of Set 11 | tongren
# Processing Record 17 of Set 11 | prince george
# Processing Record 18 of Set 11 | kuching
# Processing Record 19 of Set 11 | valparaiso
# Processing Record 20 of Set 11 | yima
# Processing Record 21 of Set 11 | puerto san carlos
# City not found. Skipping...
# Processing Record 22 of Set 11 | angola
# Processing Record 23 of Set 11 | baardheere
# Processing Record 24 of Set 11 | anloga
# Processing Record 25 of Set 11 | swiecie
# Processing Record 26 of Set 11 | hassi messaoud
# Processing Record 27 of Set 11 | alofi
# Processing Record 28 of Set 11 | yacuiba
# Processing Record 29 of Set 11 | gamla uppsala
# Processing Record 30 of Set 11 | buka
# Processing Record 31 of Set 11 | hafar al-batin
# Processing Record 32 of Set 11 | juan griego
# Processing Record 33 of Set 11 | gannan
# Processing Record 34 of Set 11 | qalat
# Processing Record 35 of Set 11 | kayangel
# Processing Record 36 of Set 11 | peto
# Processing Record 37 of Set 11 | barbacoas
# Processing Record 38 of Set 11 | smithers
# Processing Record 39 of Set 11 | ayaguz
# City not found. Skipping...
# Processing Record 40 of Set 11 | lyepyel'
# Processing Record 41 of Set 11 | zinder
# Processing Record 42 of Set 11 | greenville
# Processing Record 43 of Set 11 | porto novo
# Processing Record 44 of Set 11 | kerikeri
# Processing Record 45 of Set 11 | mizdah
# Processing Record 46 of Set 11 | dapa
# Processing Record 47 of Set 11 | xai-xai
# Processing Record 48 of Set 11 | zalari
# Processing Record 49 of Set 11 | al manaqil
# Processing Record 0 of Set 12 | santa ana
# Processing Record 1 of Set 12 | ust'-kulom
# Processing Record 2 of Set 12 | tuba city
# Processing Record 3 of Set 12 | yerofey pavlovich
# Processing Record 4 of Set 12 | necochea
# Processing Record 5 of Set 12 | yeniseysk
# Processing Record 6 of Set 12 | klaksvik
# Processing Record 7 of Set 12 | smolensk
# Processing Record 8 of Set 12 | kone
# Processing Record 9 of Set 12 | krasnyy chikoy
# Processing Record 10 of Set 12 | lionel town
# Processing Record 11 of Set 12 | olinda
# Processing Record 12 of Set 12 | ormara
# Processing Record 13 of Set 12 | sao felix do xingu
# Processing Record 14 of Set 12 | svetlyy
# Processing Record 15 of Set 12 | tayaman
# Processing Record 16 of Set 12 | lazaro cardenas
# Processing Record 17 of Set 12 | hit
# Processing Record 18 of Set 12 | saqqez
# Processing Record 19 of Set 12 | udi
# Processing Record 20 of Set 12 | daund
# Processing Record 21 of Set 12 | bodaybo
# Processing Record 22 of Set 12 | shimoda
# Processing Record 23 of Set 12 | zhaoyuan
# Processing Record 24 of Set 12 | revda
# Processing Record 25 of Set 12 | balsas
# Processing Record 26 of Set 12 | birjand
# Processing Record 27 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 28 of Set 12 | asau
# Processing Record 29 of Set 12 | bayanhongor
# Processing Record 30 of Set 12 | howard springs
# Processing Record 31 of Set 12 | arauco
# Processing Record 32 of Set 12 | batang
# Processing Record 33 of Set 12 | inza
# Processing Record 34 of Set 12 | nova vicosa
# Processing Record 35 of Set 12 | nar'yan-mar
# Processing Record 36 of Set 12 | barra de santo antonio
# Processing Record 37 of Set 12 | enriquillo
# Processing Record 38 of Set 12 | tongliao
# Processing Record 39 of Set 12 | novo aripuana
# Processing Record 40 of Set 12 | grajau
# Processing Record 41 of Set 12 | hasaki
# Processing Record 42 of Set 12 | sabang
# Processing Record 43 of Set 12 | kayes
# Processing Record 44 of Set 12 | ancud
# Processing Record 45 of Set 12 | tashla
# Processing Record 46 of Set 12 | tobelo
# Processing Record 47 of Set 12 | selfoss
# Processing Record 48 of Set 12 | mincivan
# Processing Record 49 of Set 12 | at taj
# Processing Record 0 of Set 13 | colonia
# Processing Record 1 of Set 13 | hauterive
# Processing Record 2 of Set 13 | katima mulilo
# Processing Record 3 of Set 13 | key west
# Processing Record 4 of Set 13 | midvagur
# Processing Record 5 of Set 13 | mount gambier
# Processing Record 6 of Set 13 | kapit
# Processing Record 7 of Set 13 | umm kaddadah
# Processing Record 8 of Set 13 | uvalde
# Processing Record 9 of Set 13 | souillac
# Processing Record 10 of Set 13 | sumbawa besar
# Processing Record 11 of Set 13 | tezu
# Processing Record 12 of Set 13 | dryden
# Processing Record 13 of Set 13 | puerto deseado
# Processing Record 14 of Set 13 | skive
# Processing Record 15 of Set 13 | cotusca
# Processing Record 16 of Set 13 | gaspe
# Processing Record 17 of Set 13 | nay pyi taw
# Processing Record 18 of Set 13 | litayan
# Processing Record 19 of Set 13 | tete
# Processing Record 20 of Set 13 | porkhov
# Processing Record 21 of Set 13 | nikol'sk
# Processing Record 22 of Set 13 | new norfolk
# Processing Record 23 of Set 13 | touros
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
                            
# Show Record Count
city_data_df.count()
# Out:
# City          600
# Lat           600
# Lng           600
# Max Temp      600
# Humidity      600
# Cloudiness    600
# Wind Speed    600
# Country       600
# Date          600
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        bredasdorp -34.5322   20.0403     81.39        44           0
# 1         adamstown -25.0660 -130.1015     76.95        76           0
# 2         grytviken -54.2811  -36.5092     43.54        80          25
# 3           susuman  62.7833  148.1667    -13.22        95         100
# 4         papatowai -46.5619  169.4708     44.17        83          90
#
#          Wind Speed Country        Date
# City_ID
# 0              8.90      ZA  1709984463
# 1             13.00      PN  1709984463
# 2              6.96      GS  1709984463
# 3              2.15      RU  1709984464
# 4              5.46      NZ  1709984464

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
x_axis_df1 = city_data_df["Lat"]
y_axis_df1 = city_data_df["Max Temp"]
plt.scatter(x_axis_df1, y_axis_df1)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Temperature (2022-10-18)')
# YOUR CODE HERE
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
x_axis_df2 = city_data_df["Lat"]
y_axis_df2 = city_data_df["Humidity"]
plt.scatter(x_axis_df2, y_axis_df2)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Humidity (2022-10-18)')
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
x_axis_df3 = city_data_df["Lat"]
y_axis_df3 = city_data_df["Cloudiness"]
plt.scatter(x_axis_df3, y_axis_df3)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Humidity (2022-10-18)')
# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
x_axis_df4 = city_data_df["Lat"]
y_axis_df4 = city_data_df["Wind Speed"]
plt.scatter(x_axis_df4, y_axis_df4)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Humidity (2022-10-18)')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
from scipy import stats

### i addedd these commeents Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)

#### i addedd these commeents Get regression values
regress_values = x_axis* slope + intercept

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
north_df = pd.DataFrame(city_data)

northern_hemi_df = north_df[north_df['Lat'] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 3      susuman  62.7833  148.1667    -13.22        95         100        2.15
# 5    ilulissat  69.2167  -51.1000      3.22        78          75       10.36
# 6   whitehorse  60.7161 -135.0538     30.97        64          75       10.36
# 9       bethel  41.3712  -73.4140     39.76        81         100        3.00
# 12     skrunda  56.6833   22.0167     40.71        54          89        3.96
#
#    Country        Date
# 3       RU  1709984464
# 5       GL  1709984464
# 6       CA  1709984465
# 9       US  1709984466
# 12      LV  1709984467

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
south_df = pd.DataFrame(city_data)

southern_hemi_df = south_df[south_df['Lat'] <=0]
# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         bredasdorp -34.5322   20.0403     81.39        44           0
# 1          adamstown -25.0660 -130.1015     76.95        76           0
# 2          grytviken -54.2811  -36.5092     43.54        80          25
# 4          papatowai -46.5619  169.4708     44.17        83          90
# 7  port-aux-francais -49.3500   70.2167     43.63        98         100
#
#    Wind Speed Country        Date
# 0        8.90      ZA  1709984463
# 1       13.00      PN  1709984463
# 2        6.96      GS  1709984463
# 4        5.46      NZ  1709984464
# 7       29.82      TF  1709984465

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

x_axis_df5 = northern_hemi_df["Lat"]
y_axis_df5 = northern_hemi_df["Max Temp"]


#### i addedd these commeents Get regression values
regress_values = x_axis_df5 * slope + intercept
print(regress_values)

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# i addedd these commeents Create Plot
plt.scatter(x_axis_df5,y_axis_df5)
plt.plot(y_axis_df5,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# 3      8.925866
# 5      8.807595
# 6      8.963869
# 9      9.319504
# 12     9.038008
#          ...
# 592    9.182319
# 593    9.717077
# 594    9.945207
# 596    9.018122
# 597    9.092505
# Name: Lat, Length: 425, dtype: float64
# y = -0.02x +10.08
# The r-value is: 0.009730949788848363

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

x_axis_df6 = southern_hemi_df["Lat"]
y_axis_df6 = southern_hemi_df["Max Temp"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df6, y_axis_df6)

#### i addedd these commeents Get regression values
regress_values = x_axis_df6 * slope + intercept
print(regress_values)

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# i addedd these commeents Create Plot
plt.scatter(x_axis_df6,y_axis_df6)
plt.plot(x_axis_df6,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# 0      68.435951
# 1      73.628483
# 2      57.603010
# 4      61.837253
# 7      60.307886
#          ...
# 586    82.715496
# 589    61.185375
# 595    78.515701
# 598    63.910327
# 599    84.526261
# Name: Lat, Length: 175, dtype: float64
# y = 0.55x +87.38
# The r-value is: 0.41908356484519454

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_axis_df5 = northern_hemi_df["Lat"]
y_axis_df5 = northern_hemi_df["Humidity"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df5, y_axis_df5)

#### i addedd these commeents Get regression values
regress_values = x_axis_df5 * slope + intercept
print(regress_values)

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# i addedd these commeents Create Plot
plt.scatter(x_axis_df5,y_axis_df5)
plt.plot(y_axis_df5,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# 0      58.334981
# 1      81.320621
# 2      84.995953
# 5      59.638666
# 7      65.208476
#          ...
# 93     81.862402
# 94     81.077910
# 96     62.073438
# 99     65.481216
# 100    73.047132
# Name: Lat, Length: 68, dtype: float64
# y = 0.45x +53.7
# The r-value is: 0.16030777271892407

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_axis_df6 = southern_hemi_df["Lat"]
y_axis_df6 = southern_hemi_df["Humidity"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df6, y_axis_df6)

#### i addedd these commeents Get regression values
regress_values = x_axis_df6 * slope + intercept
print(regress_values)

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# i addedd these commeents Create Plot
plt.scatter(x_axis_df6,y_axis_df6)
plt.plot(x_axis_df6,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# 3     80.295651
# 4     79.147976
# 6     82.330372
# 10    79.477250
# 11    77.351478
# 12    78.005745
# 16    76.890769
# 17    80.948245
# 25    78.147704
# 27    82.298996
# 32    76.690724
# 33    79.123595
# 35    81.184601
# 37    79.846981
# 39    79.332321
# 40    82.223270
# 43    76.753635
# 51    78.168291
# 52    77.063704
# 53    82.277027
# 54    79.063764
# 57    80.763416
# 61    80.747473
# 68    78.840586
# 72    82.587897
# 74    81.860752
# 81    82.428903
# 82    82.301845
# 85    83.245001
# 87    83.261890
# 95    83.327565
# 97    80.238559
# 98    78.774014
# Name: Lat, dtype: float64
# y = 0.12x +83.33
# The r-value is: 0.013143127459769515

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_axis_df5 = northern_hemi_df["Lat"]
y_axis_df5 = northern_hemi_df["Cloudiness"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df5, y_axis_df5)

#### i addedd these commeents Get regression values
regress_values = x_axis_df5 * slope + intercept
print(regress_values)

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# i addedd these commeents Create Plot
plt.scatter(x_axis_df5,y_axis_df5)
plt.plot(y_axis_df5,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# 0      60.641807
# 1      72.740235
# 2      74.674736
# 5      61.327998
# 7      64.259652
#          ...
# 93     73.025400
# 94     72.612485
# 96     62.609533
# 99     64.403208
# 100    68.385507
# Name: Lat, Length: 68, dtype: float64
# y = 0.24x +58.2
# The r-value is: 0.016229043140239447

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_axis_df6 = southern_hemi_df["Lat"]
y_axis_df6 = southern_hemi_df["Cloudiness"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df6, y_axis_df6)

#### i addedd these commeents Get regression values
regress_values = x_axis_df6 * slope + intercept
print(regress_values)

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# i addedd these commeents Create Plot
plt.scatter(x_axis_df6,y_axis_df6)
plt.plot(x_axis_df6,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# 3     48.897097
# 4     46.821016
# 6     52.577798
# 10    47.416654
# 11    43.571248
# 12    44.754782
# 16    42.737850
# 17    50.077605
# 25    45.011578
# 27    52.521039
# 32    42.375980
# 33    46.776912
# 35    50.505160
# 37    48.085478
# 39    47.154485
# 40    52.384055
# 43    42.489783
# 51    45.048818
# 52    43.050681
# 53    52.481300
# 54    46.668680
# 57    49.743259
# 61    49.714419
# 68    46.264965
# 72    53.043646
# 74    51.728281
# 81    52.756036
# 82    52.526193
# 85    54.232312
# 87    54.262862
# 95    54.381665
# 97    48.793822
# 98    46.144539
# Name: Lat, dtype: float64
# y = 0.22x +54.39
# The r-value is: 0.008426906289703419

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_axis_df5 = northern_hemi_df["Lat"]
y_axis_df5 = northern_hemi_df["Wind Speed"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df5, y_axis_df5)

#### i addedd these commeents Get regression values
regress_values = x_axis_df5 * slope + intercept
print(regress_values)

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# i addedd these commeents Create Plot
plt.scatter(x_axis_df5,y_axis_df5)
plt.plot(y_axis_df5,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# 0      12.158128
# 1       8.389817
# 2       7.787276
# 5      11.944399
# 7      11.031273
#          ...
# 93      8.300996
# 94      8.429607
# 96     11.545238
# 99     10.986560
# 100     9.746189
# Name: Lat, Length: 68, dtype: float64
# y = -0.07x +12.92
# The r-value is: 0.04588741995628247

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_axis_df6 = southern_hemi_df["Lat"]
y_axis_df6 = southern_hemi_df["Wind Speed"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df6, y_axis_df6)

#### i addedd these commeents Get regression values
regress_values = x_axis_df6 * slope + intercept
print(regress_values)

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# i addedd these commeents Create Plot
plt.scatter(x_axis_df6,y_axis_df6)
plt.plot(x_axis_df6,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# 3      9.335882
# 4     10.386897
# 6      7.472530
# 10    10.085356
# 11    12.032090
# 12    11.432927
# 16    12.453997
# 17     8.738251
# 25    11.302924
# 27     7.501264
# 32    12.637193
# 33    10.409225
# 35     8.521802
# 37     9.746764
# 39    10.218079
# 40     7.570613
# 43    12.579581
# 51    11.284071
# 52    12.295626
# 53     7.521383
# 54    10.464017
# 57     8.907514
# 61     8.922114
# 68    10.668398
# 72     7.236695
# 74     7.902598
# 81     7.382298
# 82     7.498655
# 85     6.634934
# 87     6.619468
# 95     6.559324
# 97     9.388166
# 98    10.729363
# Name: Lat, dtype: float64
# y = -0.11x +6.55
# The r-value is: 0.07855164329367993

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
