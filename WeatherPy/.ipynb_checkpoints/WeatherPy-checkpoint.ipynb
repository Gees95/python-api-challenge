# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 640

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1



# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    city_weather = requests.get(city_url).json()
    
 # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ust'-uda
# Processing Record 2 of Set 1 | papatowai
# Processing Record 3 of Set 1 | nishinoomote
# Processing Record 4 of Set 1 | cockburn town
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | udachny
# Processing Record 7 of Set 1 | novodvinsk
# Processing Record 8 of Set 1 | vorgashor
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | nova vicosa
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | santa cruz
# Processing Record 13 of Set 1 | port lincoln
# Processing Record 14 of Set 1 | armacao de buzios
# Processing Record 15 of Set 1 | adamstown
# Processing Record 16 of Set 1 | port-aux-francais
# Processing Record 17 of Set 1 | phang nga
# Processing Record 18 of Set 1 | sodra sandby
# Processing Record 19 of Set 1 | darwin
# Processing Record 20 of Set 1 | grytviken
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | puerto natales
# Processing Record 23 of Set 1 | badger
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | usol'ye-sibirskoye
# Processing Record 27 of Set 1 | pacific grove
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | bonthe
# Processing Record 30 of Set 1 | vilyuchinsk
# Processing Record 31 of Set 1 | gulbarga
# Processing Record 32 of Set 1 | haiku-pauwela
# Processing Record 33 of Set 1 | qaqortoq
# Processing Record 34 of Set 1 | whitehorse
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | la ligua
# Processing Record 37 of Set 1 | wang sai phun
# Processing Record 38 of Set 1 | bondo
# Processing Record 39 of Set 1 | isafjordur
# Processing Record 40 of Set 1 | howard springs
# Processing Record 41 of Set 1 | utrik
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | ust-nera
# Processing Record 44 of Set 1 | kerikeri
# Processing Record 45 of Set 1 | kodiak
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | tosontsengel
# Processing Record 50 of Set 1 | kismayo
# Processing Record 0 of Set 2 | edinburgh of the seven seas
# Processing Record 1 of Set 2 | west island
# Processing Record 2 of Set 2 | at taj
# Processing Record 3 of Set 2 | tidjikja
# Processing Record 4 of Set 2 | yeppoon
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | malindi
# Processing Record 7 of Set 2 | takamaka
# City not found. Skipping...
# Processing Record 8 of Set 2 | rucava
# Processing Record 9 of Set 2 | mombetsu
# Processing Record 10 of Set 2 | uturoa
# Processing Record 11 of Set 2 | taoudenni
# Processing Record 12 of Set 2 | hadibu
# Processing Record 13 of Set 2 | grand-bassam
# Processing Record 14 of Set 2 | luena
# Processing Record 15 of Set 2 | pisco
# Processing Record 16 of Set 2 | al kharijah
# Processing Record 17 of Set 2 | masterton
# Processing Record 18 of Set 2 | saladas
# Processing Record 19 of Set 2 | djougou
# Processing Record 20 of Set 2 | banda aceh
# Processing Record 21 of Set 2 | praia da vitoria
# Processing Record 22 of Set 2 | karratha
# Processing Record 23 of Set 2 | susuman
# Processing Record 24 of Set 2 | fort st. john
# Processing Record 25 of Set 2 | college
# Processing Record 26 of Set 2 | norilsk
# Processing Record 27 of Set 2 | bamboo flat
# Processing Record 28 of Set 2 | cookeville
# Processing Record 29 of Set 2 | muzayri'
# City not found. Skipping...
# Processing Record 30 of Set 2 | atafu village
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | nahiyat al fuhud
# Processing Record 33 of Set 2 | bakanas
# Processing Record 34 of Set 2 | yarmouth
# Processing Record 35 of Set 2 | port hedland
# Processing Record 36 of Set 2 | korla
# Processing Record 37 of Set 2 | olonkinbyen
# Processing Record 38 of Set 2 | keflavik
# Processing Record 39 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 40 of Set 2 | belmonte
# Processing Record 41 of Set 2 | constantia
# Processing Record 42 of Set 2 | kone
# Processing Record 43 of Set 2 | lihue
# Processing Record 44 of Set 2 | enewetak
# Processing Record 45 of Set 2 | eagle pass
# Processing Record 46 of Set 2 | namsos
# Processing Record 47 of Set 2 | rikaze
# Processing Record 48 of Set 2 | ta`u
# Processing Record 49 of Set 2 | westport
# Processing Record 0 of Set 3 | champerico
# Processing Record 1 of Set 3 | ola
# Processing Record 2 of Set 3 | chibougamau
# Processing Record 3 of Set 3 | grand falls-windsor
# Processing Record 4 of Set 3 | houlton
# Processing Record 5 of Set 3 | alice springs
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | conde
# Processing Record 8 of Set 3 | thanh hoa
# Processing Record 9 of Set 3 | borogontsy
# Processing Record 10 of Set 3 | hermanus
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | guerrero negro
# Processing Record 13 of Set 3 | ixtapa
# Processing Record 14 of Set 3 | burladingen
# Processing Record 15 of Set 3 | nacala
# Processing Record 16 of Set 3 | kavaratti
# Processing Record 17 of Set 3 | richards bay
# Processing Record 18 of Set 3 | niafunke
# Processing Record 19 of Set 3 | igarka
# Processing Record 20 of Set 3 | fort frances
# Processing Record 21 of Set 3 | caleta de carquin
# Processing Record 22 of Set 3 | mili
# Processing Record 23 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 24 of Set 3 | ashland
# Processing Record 25 of Set 3 | razumnoye
# Processing Record 26 of Set 3 | broome
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | ambon
# Processing Record 29 of Set 3 | port mathurin
# Processing Record 30 of Set 3 | thabazimbi
# Processing Record 31 of Set 3 | chonchi
# Processing Record 32 of Set 3 | afaahiti
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | rexburg
# Processing Record 35 of Set 3 | chaman
# Processing Record 36 of Set 3 | namdrik
# Processing Record 37 of Set 3 | pyapon
# Processing Record 38 of Set 3 | persembe
# Processing Record 39 of Set 3 | pasni
# Processing Record 40 of Set 3 | sopishte
# Processing Record 41 of Set 3 | essaouira
# Processing Record 42 of Set 3 | letterkenny
# Processing Record 43 of Set 3 | ocean shores
# Processing Record 44 of Set 3 | kataba
# Processing Record 45 of Set 3 | happy valley-goose bay
# Processing Record 46 of Set 3 | yinchuan
# Processing Record 47 of Set 3 | newman
# Processing Record 48 of Set 3 | broken hill
# Processing Record 49 of Set 3 | new plymouth
# Processing Record 0 of Set 4 | bilibino
# Processing Record 1 of Set 4 | blackmans bay
# Processing Record 2 of Set 4 | st. john's
# Processing Record 3 of Set 4 | new norfolk
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | eirunepe
# Processing Record 6 of Set 4 | antofagasta
# Processing Record 7 of Set 4 | neryungri
# Processing Record 8 of Set 4 | hawaiian paradise park
# Processing Record 9 of Set 4 | brumado
# Processing Record 10 of Set 4 | fayzabad
# Processing Record 11 of Set 4 | fort mcmurray
# Processing Record 12 of Set 4 | invercargill
# Processing Record 13 of Set 4 | port douglas
# Processing Record 14 of Set 4 | tobelo
# Processing Record 15 of Set 4 | saipan
# Processing Record 16 of Set 4 | walvis bay
# Processing Record 17 of Set 4 | kikwit
# Processing Record 18 of Set 4 | weno
# Processing Record 19 of Set 4 | idri
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | hilo
# Processing Record 22 of Set 4 | colby
# Processing Record 23 of Set 4 | iskateley
# Processing Record 24 of Set 4 | margaret river
# Processing Record 25 of Set 4 | anadyr
# Processing Record 26 of Set 4 | port saint john's
# Processing Record 27 of Set 4 | sant lluis
# Processing Record 28 of Set 4 | nar'yan-mar
# Processing Record 29 of Set 4 | villa union
# Processing Record 30 of Set 4 | savave village
# City not found. Skipping...
# Processing Record 31 of Set 4 | tofol
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | velingara
# Processing Record 34 of Set 4 | hassi messaoud
# Processing Record 35 of Set 4 | ebon
# Processing Record 36 of Set 4 | queenstown
# Processing Record 37 of Set 4 | lengede
# Processing Record 38 of Set 4 | howrah
# Processing Record 39 of Set 4 | bengkulu
# Processing Record 40 of Set 4 | nuku'alofa
# Processing Record 41 of Set 4 | beaufort
# Processing Record 42 of Set 4 | las veredas
# Processing Record 43 of Set 4 | akwanga
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | krasnoufimsk
# Processing Record 46 of Set 4 | manokwari
# Processing Record 47 of Set 4 | kingston
# Processing Record 48 of Set 4 | barguzin
# Processing Record 49 of Set 4 | wailua homesteads
# Processing Record 0 of Set 5 | taitung city
# Processing Record 1 of Set 5 | khanty-mansiysk
# Processing Record 2 of Set 5 | tianpeng
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | itamaraca
# Processing Record 5 of Set 5 | visakhapatnam
# Processing Record 6 of Set 5 | liaoyuan
# Processing Record 7 of Set 5 | crucecita
# Processing Record 8 of Set 5 | saint croix
# Processing Record 9 of Set 5 | conakry
# Processing Record 10 of Set 5 | shitanjing
# Processing Record 11 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 12 of Set 5 | joshimath
# Processing Record 13 of Set 5 | sechura
# Processing Record 14 of Set 5 | kavieng
# Processing Record 15 of Set 5 | al ghayzah
# Processing Record 16 of Set 5 | rio gallegos
# Processing Record 17 of Set 5 | agat village
# Processing Record 18 of Set 5 | simanggang
# Processing Record 19 of Set 5 | harstad
# Processing Record 20 of Set 5 | puerto ayora
# Processing Record 21 of Set 5 | dazuocun
# Processing Record 22 of Set 5 | betio village
# Processing Record 23 of Set 5 | juan aldama
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | spearfish
# Processing Record 26 of Set 5 | chapaev
# Processing Record 27 of Set 5 | nawanshahr
# Processing Record 28 of Set 5 | laikit, laikit ii (dimembe)
# Processing Record 29 of Set 5 | tayu
# Processing Record 30 of Set 5 | saarijarvi
# Processing Record 31 of Set 5 | hamilton
# Processing Record 32 of Set 5 | kyshtovka
# Processing Record 33 of Set 5 | yangiobod
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | thinadhoo
# Processing Record 36 of Set 5 | hanceville
# Processing Record 37 of Set 5 | amga
# Processing Record 38 of Set 5 | tippi
# Processing Record 39 of Set 5 | elmendorf air force base
# City not found. Skipping...
# Processing Record 40 of Set 5 | luderitz
# Processing Record 41 of Set 5 | berbera
# Processing Record 42 of Set 5 | bontang
# Processing Record 43 of Set 5 | porto novo
# Processing Record 44 of Set 5 | kyparissia
# Processing Record 45 of Set 5 | ancud
# Processing Record 46 of Set 5 | kimberley
# Processing Record 47 of Set 5 | dongola
# Processing Record 48 of Set 5 | callaway
# Processing Record 49 of Set 5 | fale old settlement
# Processing Record 0 of Set 6 | tura
# Processing Record 1 of Set 6 | klyuchi
# Processing Record 2 of Set 6 | komsomol'skiy
# Processing Record 3 of Set 6 | zeya
# Processing Record 4 of Set 6 | pambujan
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | ferrenafe
# Processing Record 7 of Set 6 | sishilichengzi
# City not found. Skipping...
# Processing Record 8 of Set 6 | alaghsas
# Processing Record 9 of Set 6 | fengxiang
# Processing Record 10 of Set 6 | antalaha
# Processing Record 11 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 12 of Set 6 | stanley
# Processing Record 13 of Set 6 | murudeshwara
# Processing Record 14 of Set 6 | kultali
# City not found. Skipping...
# Processing Record 15 of Set 6 | umluj
# Processing Record 16 of Set 6 | buala
# Processing Record 17 of Set 6 | colonia
# Processing Record 18 of Set 6 | sierra grande
# Processing Record 19 of Set 6 | santa cecilia
# Processing Record 20 of Set 6 | cuenca
# Processing Record 21 of Set 6 | oualidia
# City not found. Skipping...
# Processing Record 22 of Set 6 | mitu
# Processing Record 23 of Set 6 | aoulef
# Processing Record 24 of Set 6 | nova sintra
# Processing Record 25 of Set 6 | tolanaro
# Processing Record 26 of Set 6 | boulder city
# Processing Record 27 of Set 6 | nanao
# Processing Record 28 of Set 6 | san andros
# City not found. Skipping...
# Processing Record 29 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 30 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 31 of Set 6 | stara vyzhivka
# Processing Record 32 of Set 6 | el granada
# Processing Record 33 of Set 6 | forster
# Processing Record 34 of Set 6 | yuanping
# Processing Record 35 of Set 6 | truth or consequences
# Processing Record 36 of Set 6 | tazovsky
# Processing Record 37 of Set 6 | hotan
# Processing Record 38 of Set 6 | chui
# Processing Record 39 of Set 6 | changyon
# Processing Record 40 of Set 6 | rezh
# Processing Record 41 of Set 6 | laguna
# Processing Record 42 of Set 6 | pariaman
# Processing Record 43 of Set 6 | faranah
# Processing Record 44 of Set 6 | luorong
# Processing Record 45 of Set 6 | thompson
# Processing Record 46 of Set 6 | la gi
# Processing Record 47 of Set 6 | nagtipunan
# Processing Record 48 of Set 6 | aasiaat
# Processing Record 49 of Set 6 | ha
# City not found. Skipping...
# Processing Record 0 of Set 7 | mukalla
# Processing Record 1 of Set 7 | lazaro cardenas
# Processing Record 2 of Set 7 | timaru
# Processing Record 3 of Set 7 | kalmunai
# Processing Record 4 of Set 7 | langfang
# Processing Record 5 of Set 7 | bathsheba
# Processing Record 6 of Set 7 | salina
# Processing Record 7 of Set 7 | turan
# Processing Record 8 of Set 7 | major isidoro
# Processing Record 9 of Set 7 | gilgit
# Processing Record 10 of Set 7 | east london
# Processing Record 11 of Set 7 | olyokminsk
# Processing Record 12 of Set 7 | las varillas
# Processing Record 13 of Set 7 | las tablas
# Processing Record 14 of Set 7 | zhangatas
# Processing Record 15 of Set 7 | egilsstadir
# Processing Record 16 of Set 7 | santyoku
# Processing Record 17 of Set 7 | ziro
# Processing Record 18 of Set 7 | cable beach
# City not found. Skipping...
# Processing Record 19 of Set 7 | volokonovka
# Processing Record 20 of Set 7 | swan hill
# Processing Record 21 of Set 7 | sao joao da barra
# Processing Record 22 of Set 7 | malango
# Processing Record 23 of Set 7 | arkalyk
# Processing Record 24 of Set 7 | dattapur
# Processing Record 25 of Set 7 | yemva
# Processing Record 26 of Set 7 | pechora
# Processing Record 27 of Set 7 | rawson
# Processing Record 28 of Set 7 | grafton
# Processing Record 29 of Set 7 | sumbe
# Processing Record 30 of Set 7 | punta arenas
# Processing Record 31 of Set 7 | springs
# Processing Record 32 of Set 7 | portland
# Processing Record 33 of Set 7 | trevelin
# Processing Record 34 of Set 7 | vernon
# Processing Record 35 of Set 7 | auki
# Processing Record 36 of Set 7 | kapchorwa
# Processing Record 37 of Set 7 | quang ngai
# Processing Record 38 of Set 7 | fortaleza
# Processing Record 39 of Set 7 | lethem
# Processing Record 40 of Set 7 | puerto colombia
# Processing Record 41 of Set 7 | tual
# Processing Record 42 of Set 7 | bougouni
# Processing Record 43 of Set 7 | jamestown
# Processing Record 44 of Set 7 | abidjan
# Processing Record 45 of Set 7 | kruisfontein
# Processing Record 46 of Set 7 | mangalia
# Processing Record 47 of Set 7 | chinde
# Processing Record 48 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 49 of Set 7 | souillac
# Processing Record 0 of Set 8 | lukolela
# Processing Record 1 of Set 8 | clifton
# Processing Record 2 of Set 8 | toliara
# Processing Record 3 of Set 8 | mount pearl
# Processing Record 4 of Set 8 | erbil
# Processing Record 5 of Set 8 | riverton
# Processing Record 6 of Set 8 | tadine
# Processing Record 7 of Set 8 | wenling
# Processing Record 8 of Set 8 | aginskoye
# Processing Record 9 of Set 8 | hastings
# Processing Record 10 of Set 8 | nemuro
# Processing Record 11 of Set 8 | coahuayana de hidalgo
# Processing Record 12 of Set 8 | peniche
# Processing Record 13 of Set 8 | itapaci
# Processing Record 14 of Set 8 | brazzaville
# Processing Record 15 of Set 8 | zara
# Processing Record 16 of Set 8 | darabani
# Processing Record 17 of Set 8 | bromolla
# City not found. Skipping...
# Processing Record 18 of Set 8 | moju
# Processing Record 19 of Set 8 | ulety
# Processing Record 20 of Set 8 | lapaha
# City not found. Skipping...
# Processing Record 21 of Set 8 | kiunga
# Processing Record 22 of Set 8 | freetown
# Processing Record 23 of Set 8 | al jawf
# Processing Record 24 of Set 8 | baiti
# Processing Record 25 of Set 8 | ma'an
# Processing Record 26 of Set 8 | konkwesso
# Processing Record 27 of Set 8 | sosnogorsk
# Processing Record 28 of Set 8 | prado
# Processing Record 29 of Set 8 | tocopilla
# Processing Record 30 of Set 8 | ulaangom
# Processing Record 31 of Set 8 | greymouth
# Processing Record 32 of Set 8 | estrela
# Processing Record 33 of Set 8 | uliastay
# Processing Record 34 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 35 of Set 8 | hirara
# Processing Record 36 of Set 8 | macenta
# Processing Record 37 of Set 8 | al khums
# Processing Record 38 of Set 8 | rio grande
# Processing Record 39 of Set 8 | mount isa
# Processing Record 40 of Set 8 | anadia
# Processing Record 41 of Set 8 | palmer
# Processing Record 42 of Set 8 | coari
# Processing Record 43 of Set 8 | key west
# Processing Record 44 of Set 8 | namibe
# Processing Record 45 of Set 8 | isla del bosque
# Processing Record 46 of Set 8 | mount gambier
# Processing Record 47 of Set 8 | ndende
# Processing Record 48 of Set 8 | coquimbo
# Processing Record 49 of Set 8 | cadale
# Processing Record 0 of Set 9 | playa del ingles
# Processing Record 1 of Set 9 | poronaysk
# Processing Record 2 of Set 9 | kasempa
# Processing Record 3 of Set 9 | urengoy
# Processing Record 4 of Set 9 | callao
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | tarfaya
# Processing Record 7 of Set 9 | dryden
# Processing Record 8 of Set 9 | sao jose da coroa grande
# Processing Record 9 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 10 of Set 9 | totness
# Processing Record 11 of Set 9 | crane
# Processing Record 12 of Set 9 | tomatlan
# Processing Record 13 of Set 9 | tamanrasset
# Processing Record 14 of Set 9 | acapulco de juarez
# Processing Record 15 of Set 9 | port-vila
# Processing Record 16 of Set 9 | waingapu
# Processing Record 17 of Set 9 | chos malal
# Processing Record 18 of Set 9 | vilyuysk
# Processing Record 19 of Set 9 | lyantor
# Processing Record 20 of Set 9 | gamay
# Processing Record 21 of Set 9 | san carlos de bariloche
# Processing Record 22 of Set 9 | nadi
# Processing Record 23 of Set 9 | xining
# Processing Record 24 of Set 9 | saratamata
# City not found. Skipping...
# Processing Record 25 of Set 9 | tete
# Processing Record 26 of Set 9 | fort bragg
# Processing Record 27 of Set 9 | remire-montjoly
# Processing Record 28 of Set 9 | quellon
# Processing Record 29 of Set 9 | illizi
# Processing Record 30 of Set 9 | port augusta
# Processing Record 31 of Set 9 | pavlodar
# Processing Record 32 of Set 9 | qarazhal
# Processing Record 33 of Set 9 | tacuarembo
# Processing Record 34 of Set 9 | long beach
# Processing Record 35 of Set 9 | nadym
# Processing Record 36 of Set 9 | ambatofinandrahana
# Processing Record 37 of Set 9 | inari
# Processing Record 38 of Set 9 | sidi bennour
# Processing Record 39 of Set 9 | qusmuryn
# Processing Record 40 of Set 9 | ormara
# Processing Record 41 of Set 9 | siem reap
# Processing Record 42 of Set 9 | diffa
# Processing Record 43 of Set 9 | nakhon thai
# Processing Record 44 of Set 9 | shush
# Processing Record 45 of Set 9 | flying fish cove
# Processing Record 46 of Set 9 | pandan
# Processing Record 47 of Set 9 | muroto-misakicho
# Processing Record 48 of Set 9 | uvira
# Processing Record 49 of Set 9 | cidreira
# Processing Record 0 of Set 10 | kangding
# Processing Record 1 of Set 10 | inhambane
# Processing Record 2 of Set 10 | ayod
# City not found. Skipping...
# Processing Record 3 of Set 10 | birzebbuga
# Processing Record 4 of Set 10 | frydlant nad ostravici
# Processing Record 5 of Set 10 | da nang
# Processing Record 6 of Set 10 | qinzhou
# Processing Record 7 of Set 10 | el porvenir
# Processing Record 8 of Set 10 | ocean pointe
# City not found. Skipping...
# Processing Record 9 of Set 10 | jining
# Processing Record 10 of Set 10 | dudinka
# Processing Record 11 of Set 10 | puerto baquerizo moreno
# Processing Record 12 of Set 10 | imperial
# Processing Record 13 of Set 10 | paracale
# Processing Record 14 of Set 10 | devoto
# Processing Record 15 of Set 10 | launceston
# Processing Record 16 of Set 10 | lerwick
# Processing Record 17 of Set 10 | zaozersk
# Processing Record 18 of Set 10 | al bardiyah
# Processing Record 19 of Set 10 | san antonio de pale
# Processing Record 20 of Set 10 | dhidhdhoo
# Processing Record 21 of Set 10 | mohyliv-podilskyi
# Processing Record 22 of Set 10 | usogorsk
# Processing Record 23 of Set 10 | ifon
# Processing Record 24 of Set 10 | talcahuano
# Processing Record 25 of Set 10 | dogondoutchi
# Processing Record 26 of Set 10 | williams lake
# Processing Record 27 of Set 10 | nellore
# Processing Record 28 of Set 10 | west valley
# Processing Record 29 of Set 10 | brisas barra de suchiate
# Processing Record 30 of Set 10 | cao bang
# Processing Record 31 of Set 10 | talnakh
# Processing Record 32 of Set 10 | nyagan
# Processing Record 33 of Set 10 | nabire
# Processing Record 34 of Set 10 | miri
# Processing Record 35 of Set 10 | gadzhiyevo
# Processing Record 36 of Set 10 | arjawinangun
# Processing Record 37 of Set 10 | nguigmi
# Processing Record 38 of Set 10 | kurara
# Processing Record 39 of Set 10 | berezovyy
# Processing Record 40 of Set 10 | borujen
# Processing Record 41 of Set 10 | morehead city
# Processing Record 42 of Set 10 | pedro juan caballero
# Processing Record 43 of Set 10 | vila do maio
# Processing Record 44 of Set 10 | tocache
# Processing Record 45 of Set 10 | hazaribagh
# Processing Record 46 of Set 10 | luau
# Processing Record 47 of Set 10 | xincheng
# Processing Record 48 of Set 10 | porbandar
# Processing Record 49 of Set 10 | kostinbrod
# Processing Record 0 of Set 11 | thunder bay
# Processing Record 1 of Set 11 | olney
# Processing Record 2 of Set 11 | kuala terengganu
# Processing Record 3 of Set 11 | aracuai
# Processing Record 4 of Set 11 | acucena
# Processing Record 5 of Set 11 | salekhard
# Processing Record 6 of Set 11 | lata
# Processing Record 7 of Set 11 | afif
# Processing Record 8 of Set 11 | embarcacion
# Processing Record 9 of Set 11 | nueva gerona
# Processing Record 10 of Set 11 | grantsville
# Processing Record 11 of Set 11 | ambovombe
# Processing Record 12 of Set 11 | taltal
# Processing Record 13 of Set 11 | touros
# Processing Record 14 of Set 11 | newborough
# Processing Record 15 of Set 11 | crescent city
# Processing Record 16 of Set 11 | la sarre
# Processing Record 17 of Set 11 | dakhla
# Processing Record 18 of Set 11 | sarandi grande
# Processing Record 19 of Set 11 | tralee
# Processing Record 20 of Set 11 | minas de marcona
# Processing Record 21 of Set 11 | marquette
# Processing Record 22 of Set 11 | silute
# Processing Record 23 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 24 of Set 11 | alpine
# Processing Record 25 of Set 11 | saint-joseph
# Processing Record 26 of Set 11 | ca mau
# Processing Record 27 of Set 11 | tuburan
# Processing Record 28 of Set 11 | kirensk
# Processing Record 29 of Set 11 | sofifi
# City not found. Skipping...
# Processing Record 30 of Set 11 | xocali
# Processing Record 31 of Set 11 | martil
# Processing Record 32 of Set 11 | kisangani
# Processing Record 33 of Set 11 | kamina
# Processing Record 34 of Set 11 | vadso
# Processing Record 35 of Set 11 | oranjemund
# Processing Record 36 of Set 11 | balve
# Processing Record 37 of Set 11 | talakan
# Processing Record 38 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 39 of Set 11 | zhezqazghan
# Processing Record 40 of Set 11 | hinton
# Processing Record 41 of Set 11 | aberdeen
# Processing Record 42 of Set 11 | nantucket
# Processing Record 43 of Set 11 | oltinko'l
# Processing Record 44 of Set 11 | sinan
# Processing Record 45 of Set 11 | mana
# Processing Record 46 of Set 11 | mermoz boabab
# Processing Record 47 of Set 11 | katsuren-haebaru
# Processing Record 48 of Set 11 | saint-pierre
# Processing Record 49 of Set 11 | qui nhon
# Processing Record 0 of Set 12 | inirida
# Processing Record 1 of Set 12 | vetluga
# Processing Record 2 of Set 12 | gracemere
# Processing Record 3 of Set 12 | port glaud
# City not found. Skipping...
# Processing Record 4 of Set 12 | charters towers
# Processing Record 5 of Set 12 | bikenibeu village
# Processing Record 6 of Set 12 | yagry
# City not found. Skipping...
# Processing Record 7 of Set 12 | vi
# City not found. Skipping...
# Processing Record 8 of Set 12 | mendi
# Processing Record 9 of Set 12 | khandyga
# Processing Record 10 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 12 | usinsk
# Processing Record 12 of Set 12 | nazyvayevsk
# Processing Record 13 of Set 12 | gaspe
# Processing Record 14 of Set 12 | sona
# Processing Record 15 of Set 12 | huron
# Processing Record 16 of Set 12 | baganga
# Processing Record 17 of Set 12 | ifrane
# Processing Record 18 of Set 12 | pyt-yakh
# Processing Record 19 of Set 12 | moab
# Processing Record 20 of Set 12 | hasaki
# Processing Record 21 of Set 12 | bandarbeyla
# Processing Record 22 of Set 12 | genhe
# Processing Record 23 of Set 12 | alta
# Processing Record 24 of Set 12 | gisborne
# Processing Record 25 of Set 12 | san julian
# Processing Record 26 of Set 12 | lichinga
# Processing Record 27 of Set 12 | east end
# Processing Record 28 of Set 12 | tinajo
# Processing Record 29 of Set 12 | sinabang
# Processing Record 30 of Set 12 | anloga
# Processing Record 31 of Set 12 | havre
# Processing Record 32 of Set 12 | kyabe
# Processing Record 33 of Set 12 | ghadamis
# Processing Record 34 of Set 12 | igrim
# Processing Record 35 of Set 12 | yuzhno-kurilsk
# Processing Record 36 of Set 12 | west bay
# Processing Record 37 of Set 12 | lensk
# Processing Record 38 of Set 12 | sosnovo-ozerskoye
# Processing Record 39 of Set 12 | gaillimh
# Processing Record 40 of Set 12 | geraldton
# Processing Record 41 of Set 12 | el bauga
# Processing Record 42 of Set 12 | northam
# Processing Record 43 of Set 12 | kapustin yar
# Processing Record 44 of Set 12 | huayin
# Processing Record 45 of Set 12 | aritao
# Processing Record 46 of Set 12 | arno
# Processing Record 47 of Set 12 | makushino
# Processing Record 48 of Set 12 | anse royale
# Processing Record 49 of Set 12 | ordos
# City not found. Skipping...
# Processing Record 0 of Set 13 | papao
# Processing Record 1 of Set 13 | labasa
# Processing Record 2 of Set 13 | cooma
# Processing Record 3 of Set 13 | dapa
# Processing Record 4 of Set 13 | sabang
# Processing Record 5 of Set 13 | bodo
# Processing Record 6 of Set 13 | aykol
# City not found. Skipping...
# Processing Record 7 of Set 13 | gavrilov-yam
# Processing Record 8 of Set 13 | daru
# Processing Record 9 of Set 13 | cooper's town
# Processing Record 10 of Set 13 | panaba
# Processing Record 11 of Set 13 | boden
# Processing Record 12 of Set 13 | tagaw-bay
# Processing Record 13 of Set 13 | nikolayevsk-on-amure
# Processing Record 14 of Set 13 | kilindoni
# Processing Record 15 of Set 13 | jiwani
# Processing Record 16 of Set 13 | rimouski
# Processing Record 17 of Set 13 | kapa'a
# Processing Record 18 of Set 13 | lalibela
# Processing Record 19 of Set 13 | amungan
# Processing Record 20 of Set 13 | salinas
# Processing Record 21 of Set 13 | toga village
# City not found. Skipping...
# Processing Record 22 of Set 13 | fuyu
# Processing Record 23 of Set 13 | sisimiut
# Processing Record 24 of Set 13 | rabo de peixe
# Processing Record 25 of Set 13 | mount darwin
# Processing Record 26 of Set 13 | rongelap
# Processing Record 27 of Set 13 | fada
# Processing Record 28 of Set 13 | victoria falls
# Processing Record 29 of Set 13 | ciudad sabinas hidalgo
# Processing Record 30 of Set 13 | nago
# Processing Record 31 of Set 13 | aroma
# Processing Record 32 of Set 13 | prince albert
# Processing Record 33 of Set 13 | borodulikha
# Processing Record 34 of Set 13 | el calafate
# Processing Record 35 of Set 13 | seaside
# Processing Record 36 of Set 13 | dayr mawas
# Processing Record 37 of Set 13 | babayevo
# Processing Record 38 of Set 13 | temiskaming shores
# Processing Record 39 of Set 13 | labytnangi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
                            
# Show Record Count
city_data_df.count()
# Out:
# City          606
# Lat           606
# Lng           606
# Max Temp      606
# Humidity      606
# Cloudiness    606
# Wind Speed    606
# Country       606
# Date          606
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       ust'-uda  54.1742  103.0304     20.48        98         100
# 1      papatowai -46.5619  169.4708     56.21        64          58
# 2   nishinoomote  30.7333  131.0000     58.62        85         100
# 3  cockburn town  21.4612  -71.1419     78.67        74           0
# 4           lebu -37.6167  -73.6500     62.20        72           0
#
#    Wind Speed Country        Date
# 0        2.28      RU  1710194537
# 1        3.44      NZ  1710194421
# 2       27.85      JP  1710194538
# 3        8.32      TC  1710194538
# 4       17.34      CL  1710194401

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             ust'-uda  54.1742  103.0304     20.48        98         100
# 1            papatowai -46.5619  169.4708     56.21        64          58
# 2         nishinoomote  30.7333  131.0000     58.62        85         100
# 3        cockburn town  21.4612  -71.1419     78.67        74           0
# 4                 lebu -37.6167  -73.6500     62.20        72           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.28      RU  1710194537
# 1              3.44      NZ  1710194421
# 2             27.85      JP  1710194538
# 3              8.32      TC  1710194538
# 4             17.34      CL  1710194401

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
x_axis_df1 = city_data_df["Lat"]
y_axis_df1 = city_data_df["Max Temp"]
plt.scatter(x_axis_df1, y_axis_df1)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Temperature (2022-10-18)')
# YOUR CODE HERE
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
x_axis_df2 = city_data_df["Lat"]
y_axis_df2 = city_data_df["Humidity"]
plt.scatter(x_axis_df2, y_axis_df2)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Humidity (2022-10-18)')
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
x_axis_df3 = city_data_df["Lat"]
y_axis_df3 = city_data_df["Cloudiness"]
plt.scatter(x_axis_df3, y_axis_df3)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Humidity (2022-10-18)')
# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
x_axis_df4 = city_data_df["Lat"]
y_axis_df4 = city_data_df["Wind Speed"]
plt.scatter(x_axis_df4, y_axis_df4)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Humidity (2022-10-18)')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
from scipy import stats

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
north_df = pd.DataFrame(city_data)

northern_hemi_df = north_df[north_df['Lat'] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       ust'-uda  54.1742  103.0304     20.48        98         100
# 2   nishinoomote  30.7333  131.0000     58.62        85         100
# 3  cockburn town  21.4612  -71.1419     78.67        74           0
# 5        udachny  66.4167  112.4000      0.52        99          99
# 6     novodvinsk  64.4165   40.8122     31.78        92         100
#
#    Wind Speed Country        Date
# 0        2.28      RU  1710194537
# 2       27.85      JP  1710194538
# 3        8.32      TC  1710194538
# 5        3.85      RU  1710194438
# 6        4.94      RU  1710194538

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
south_df = pd.DataFrame(city_data)

southern_hemi_df = south_df[south_df['Lat'] <=0]
# Display sample data
southern_hemi_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1     papatowai -46.5619  169.4708     56.21        64          58
# 4          lebu -37.6167  -73.6500     62.20        72           0
# 9   nova vicosa -17.8919  -39.3719     79.68        89          94
# 10     waitangi -43.9535 -176.5597     55.81        76          92
# 11   santa cruz -17.8000  -63.1667     87.64        58         100
#
#     Wind Speed Country        Date
# 1         3.44      NZ  1710194421
# 4        17.34      CL  1710194401
# 9         6.15      BR  1710194538
# 10        4.00      NZ  1710194415
# 11        9.48      BO  1710194539

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

x_axis_df5 = northern_hemi_df["Lat"]
y_axis_df5 = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df5, y_axis_df5)

regress_values = x_axis_df5 * slope + intercept

line_equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create a scatter plot with the regression line
plt.scatter(x_axis_df5, y_axis_df5, label="Data Points")
plt.plot(x_axis_df5, regress_values, "r-", label="Regression Line")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_equation, (0, 0), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
plt.legend()
plt.savefig("../output_data/North-Temp-lat.png")

plt.show()
# Out:
# The r-value is: 0.7715377030390748

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

x_axis_df6 = southern_hemi_df["Lat"]
y_axis_df6 = southern_hemi_df["Max Temp"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df6, y_axis_df6)

#### i addedd these commeents Get regression values
regress_values = x_axis_df6 * slope + intercept

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# i addedd these commeents Create Plot
plt.scatter(x_axis_df6,y_axis_df6, label="Data Points")
plt.plot(x_axis_df6,regress_values,"r-", label="Regression Line")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(0,0),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/South-Temp-lat.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.41964136719855677

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_axis_df7 = northern_hemi_df["Lat"]
y_axis_df7 = northern_hemi_df["Humidity"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df7, y_axis_df7)

#### i addedd these commeents Get regression values
regress_values = x_axis_df7 * slope + intercept

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# i addedd these commeents Create Plot
plt.scatter(x_axis_df7,y_axis_df7)
plt.plot(x_axis_df7,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(0,0),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/North-humi-lat.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.09819326991053874

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_axis_df8 = southern_hemi_df["Lat"]
y_axis_df8 = southern_hemi_df["Humidity"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df8, y_axis_df8)

#### i addedd these commeents Get regression values
regress_values = x_axis_df8 * slope + intercept

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# i addedd these commeents Create Plot
plt.scatter(x_axis_df8,y_axis_df8)
plt.plot(x_axis_df8,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/south-humi-lat.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.08755335693652666

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_axis_df9 = northern_hemi_df["Lat"]
y_axis_df9 = northern_hemi_df["Cloudiness"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df9, y_axis_df9)

#### i addedd these commeents Get regression values
regress_values = x_axis_df9 * slope + intercept

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# i addedd these commeents Create Plot
plt.scatter(x_axis_df9,y_axis_df9)

plt.plot(x_axis_df9,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')

plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/north-clodi-lat.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.06422530162208526

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_axis_df10 = southern_hemi_df["Lat"]
y_axis_df10 = southern_hemi_df["Cloudiness"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df10,y_axis_df10)

#### i addedd these commeents Get regression values
regress_values = x_axis_df10 * slope + intercept

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# i addedd these commeents Create Plot
plt.scatter(x_axis_df10,y_axis_df10)
plt.plot(x_axis_df10,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/south-clodi-lat.png")

# Show plot
plt.show()
# Out:
# y = 0.83x +81.2
# The r-value is: 0.09668960405875969

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_axis_df11 = northern_hemi_df["Lat"]
y_axis_df11 = northern_hemi_df["Wind Speed"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df11, y_axis_df11)

#### i addedd these commeents Get regression values
regress_values = x_axis_df11 * slope + intercept

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# i addedd these commeents Create Plot
plt.scatter(x_axis_df11,y_axis_df11)

plt.plot(x_axis_df11,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(0,0),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/noth-wind-lat.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.011985026884889357

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_axis_df12 = southern_hemi_df["Lat"]
y_axis_df12 = southern_hemi_df["Wind Speed"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis_df12, y_axis_df12)

#### i addedd these commeents Get regression values
regress_values = x_axis_df12 * slope + intercept

# i addedd these commeents Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# i addedd these commeents Create Plot
plt.scatter(x_axis_df12,y_axis_df12)
plt.plot(x_axis_df12,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("../output_data/south-wind-lat.png")

# Show plot
plt.show()
# Out:
# y = -0.04x +7.54
# The r-value is: 0.01122129941588664

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
''' The relationship between Temperuture and Lattitude
.  the Northern Hemisphere, the scatter plot shows data points for maximum temperature versus latitude. 
    The linear regression line equation suggests a negative correlation between latitude and maximum temperature, 
    meaning as you move away from the equator (increasing latitude), the maximum temperature tends to decrease.
. Similarly scatter plot for the Southern Hemisphere, given the negative latitudes. 
    The linear regression line has a positive slope, indicating a positive correlation between latitude and temperature in the Southern Hemisphere. 
    This would imply that as one moves towards the equator,  the temperature increases

The relationship between Humidity and Lattitude
.For the northern hemisphere, the linear regression line is upward sloping. 
    indicating a positive correlation between humidity and latitude. 
    This suggests that as one moves away from the equator towards the north pole, humidity levels tend to increase
. we see a similar upward trend with the regression line. 
    This would suggest that in the southern hemisphere, humidity also increases as latitude increases (moving away from the equator). 


The relationship between cloudiness and Lattitude
. The nothern hemisphere data indicates that there is a positive correlation between latitude and temperature, 
    which means as the latitude increases (moving away from the equator towards the pole), and the temperature also increases. 
. yet again, we see similarly to the first image, the southern hemisphere data suggests this line also appears to have a positive slope, 
    which would indicate that in the southern hemisphere, temperatures tend to increase as you move away from the equator towards the pole.

The relationship between Wind Speed and Lattitude
. In summary for this sections, the Northern Hemisphere, there is a slight positive correlation between latitude and wind speed, 
    suggesting wind speed increases as one moves away from the equator. While in the Southern Hemisphere, 
    the correlation between latitude and wind speed is negligible, implying that latitude isn't a strong predictor of wind speed in this data set. 
    The plots indicate that other factors likely have a more significant impact on wind speed than just latitude. '''
